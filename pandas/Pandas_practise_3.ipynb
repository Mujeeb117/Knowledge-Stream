# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from IPython.display import display
from IPython.display import Image
sns.set_context("notebook")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extracting Data and Filtering
# :The `[]` operator supports array of booleans as an input. In this case, the array must be exactly as long as the number of rows.
#
# The result is a **filtered version of the data frame**, where **only rows corresponding to True appear**.
#
# # Q1.
# Select multiple criteria by creating multiple boolean Series and combining them using the `&` operator. For Examole Result is win and %win is more than 50.

# %%
 # reading a CSV file into a data frame
df=pd.read_csv('elections.csv')
df
 # if we end a cell with an expression or variable name, the result will print the data frame
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# 4    54.574789
# ..         ...
# 177   1.073699
# 178  51.311515
# 179  46.858542
# 180   1.177979
# 181   0.255731
#
# [182 rows x 6 columns]

# %% [markdown]
# We will nowe work with a dataset containing the names of all babies born in California, USA. Visit the [Social Security Adminisitration Website](https://www.ssa.gov/oact/babynames/limits.html) for more details about the dataset if you want.

# %% [markdown]
# **Let's start by loading the Baby Names dataset.**

# %%
import urllib.request
import os.path
import zipfile
import pandas as pd

data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "babynamesbystate.zip"
if not os.path.exists(local_filename): # if the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.head(15)
# Out:
#    State Sex  Year       Name  Count
# 0     CA   F  1910       Mary    295
# 1     CA   F  1910      Helen    239
# 2     CA   F  1910    Dorothy    220
# 3     CA   F  1910   Margaret    163
# 4     CA   F  1910    Frances    134
# 5     CA   F  1910       Ruth    128
# 6     CA   F  1910     Evelyn    126
# 7     CA   F  1910      Alice    118
# 8     CA   F  1910   Virginia    101
# 9     CA   F  1910  Elizabeth     93
# 10    CA   F  1910   Florence     93
# 11    CA   F  1910      Marie     90
# 12    CA   F  1910    Mildred     90
# 13    CA   F  1910       Rose     74
# 14    CA   F  1910      Hazel     68

# %%
babynames.shape
# Out:
# (413894, 5)

# %% [markdown]
# # Q2.
# Calculate the some statics of babynames DataFrame using Utility Functions, like .describe(), .size, .shape and report your analysis in comments

# %%
#describe
babynames.describe()
# Out:
#                 Year          Count
# count  413894.000000  413894.000000
# mean     1986.314353      79.140348
# std        27.190404     292.028292
# min      1910.000000       5.000000
# 25%      1969.000000       7.000000
# 50%      1992.000000      13.000000
# 75%      2008.000000      38.000000
# max      2023.000000    8263.000000

# %%
#size
babynames.size
# Out:
# 2069470

# %%
#shape
babynames.shape
# Out:
# (413894, 5)

# %%
#info
babynames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413894 entries, 0 to 413893
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   State   413894 non-null  object
#  1   Sex     413894 non-null  object
#  2   Year    413894 non-null  int64
#  3   Name    413894 non-null  object
#  4   Count   413894 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 15.8+ MB

# %% [markdown]
# **Add Your comments Here**

# %% [markdown]
# # Q.3:
#
# Using the babynames DataFrame that contains baby names data for the state of California, how can you use the 'isin' method to find out which records have names that are in a given list of names, such as "Emma," "Liam," and "Olivia," and what would be the output of this operation when applied to the first 15 rows of the DataFrame (babynames.head(15))?

# %%
# List of names to check
names_list=["Emma", "Liam", "Olivia"]
# Use the isin method to filter records with names in the name_list
filtered_df=babynames[babynames ['Name'].isin(names_list)]
# Display the filtered DataFrame
filtered_df
# Out:
#        State Sex  Year    Name  Count
# 53        CA   F  1910    Emma     29
# 293       CA   F  1911    Emma     29
# 525       CA   F  1912    Emma     56
# 701       CA   F  1912  Olivia      8
# 840       CA   F  1913    Emma     56
# ...      ...  ..   ...     ...    ...
# 402535    CA   M  2020    Liam   2431
# 405071    CA   M  2020    Emma      5
# 405332    CA   M  2021    Liam   2479
# 408217    CA   M  2022    Liam   2614
# 411113    CA   M  2023    Liam   2594
#
# [286 rows x 5 columns]

# %% [markdown]
# # Q.4:
# How can you use the 'str.startswith' method in pandas to filter records in a babyname DataFrame? Provide an example code using the babynames DataFrame and explain how this method can be employed to extract data for baby names that begin with 'A' or 'B' set of letters.

# %%
# Filter rows where the 'Name' column starts with 'A'
filtered_df= babynames[babynames['Name'].str.startswith(('A', 'B'))]
# Display the filtered DataFrame
display(filtered_df)
#print("Baby names starting with 'A' and B:")
print(filtered_df)
# Out:
#        State Sex  Year      Name  Count
# 7         CA   F  1910     Alice    118
# 23        CA   F  1910   Bernice     59
# 31        CA   F  1910      Anna     51
# 32        CA   F  1910       Ann     47
# 36        CA   F  1910     Betty     40
# ...      ...  ..   ...       ...    ...
# 413597    CA   M  2023  Bradford      5
# 413598    CA   M  2023    Brahim      5
# 413599    CA   M  2023   Braiden      5
# 413600    CA   M  2023      Bret      5
# 413601    CA   M  2023  Brighton      5
#
# [62932 rows x 5 columns]
#        State Sex  Year      Name  Count
# 7         CA   F  1910     Alice    118
# 23        CA   F  1910   Bernice     59
# 31        CA   F  1910      Anna     51
# 32        CA   F  1910       Ann     47
# 36        CA   F  1910     Betty     40
# ...      ...  ..   ...       ...    ...
# 413597    CA   M  2023  Bradford      5
# 413598    CA   M  2023    Brahim      5
# 413599    CA   M  2023   Braiden      5
# 413600    CA   M  2023      Bret      5
# 413601    CA   M  2023  Brighton      5
#
# [62932 rows x 5 columns]

# %% [markdown]
# # Q.5
#
# Find the most popular baby name in California in 2012
#
# __Exercise__: Try to find the most popular baby name by finding the maximum value for 'Count' and then apply filtering to find the name.

# %%
# Step 5: Find the maximum count and the corresponding name(s)
max_count = babynames[babynames['Year'] == 2012]['Count'].max()
names_with_max_count = babynames[(babynames['Year'] == 2012) & (babynames['Count'] == max_count)]
display(names_with_max_count)
# Out:
#        State Sex  Year    Name  Count
# 197543    CA   F  2012  Sophia   3645

# %% [markdown]
# # Q. 6
# Find baby names that start with J, in th Year from 2001 to 2019
#
# *Note: To answer this question, we need a way to look at the individual characters of the baby names*

# %%
# Note: Series has powerful string manipulation methods associated with it

# Step 5: Find names that start with 'J'
names_with_J = babynames[(babynames['Name'].str.startswith('J')) & (babynames['Year'].between(2001, 2019))]
display(names_with_J)
# Out:
#        State Sex  Year         Name  Count
# 152833    CA   F  2001      Jessica   2244
# 152835    CA   F  2001     Jennifer   2027
# 152839    CA   F  2001      Jasmine   1655
# 152854    CA   F  2001   Jacqueline   1195
# 152864    CA   F  2001        Julia    983
# ...      ...  ..   ...          ...    ...
# 402352    CA   M  2019  Joseantonio      5
# 402353    CA   M  2019       Jovian      5
# 402354    CA   M  2019       Jujhar      5
# 402355    CA   M  2019      Jullian      5
# 402356    CA   M  2019         June      5
#
# [11277 rows x 5 columns]

# %% [markdown]
# # Q.7
# Add a new column called "name_length" to the babynames DataFrame, you can use .str.len() in existing Name column. Moreover. also modify the Length values with new values like existing_value-1 and rename the length column with new label as desceribe in slides.

# %%
# Calculate the length of each name and add it as a new column "_length"
babynames['name_length'] = babynames['Name'].str.len()
display(babynames)
# Modify 'name_length' values to be existing_value - 1
babynames['name_length'] = babynames['name_length'] - 1

# Rename the 'name_length' column to the new label 'name_length_modified'
babynames.rename(columns={'name_length': 'name_length_modified'}, inplace=True)

# Display the updated DataFrame
display(babynames)
# Out:
#        State Sex  Year      Name  Count  name_length
# 0         CA   F  1910      Mary    295            4
# 1         CA   F  1910     Helen    239            5
# 2         CA   F  1910   Dorothy    220            7
# 3         CA   F  1910  Margaret    163            8
# 4         CA   F  1910   Frances    134            7
# ...      ...  ..   ...       ...    ...          ...
# 413889    CA   M  2023      Ziah      5            4
# 413890    CA   M  2023    Ziaire      5            6
# 413891    CA   M  2023    Zidane      5            6
# 413892    CA   M  2023      Zyan      5            4
# 413893    CA   M  2023      Zyir      5            4
#
# [413894 rows x 6 columns]
#        State Sex  Year      Name  Count  name_length_modified
# 0         CA   F  1910      Mary    295                     3
# 1         CA   F  1910     Helen    239                     4
# 2         CA   F  1910   Dorothy    220                     6
# 3         CA   F  1910  Margaret    163                     7
# 4         CA   F  1910   Frances    134                     6
# ...      ...  ..   ...       ...    ...                   ...
# 413889    CA   M  2023      Ziah      5                     3
# 413890    CA   M  2023    Ziaire      5                     5
# 413891    CA   M  2023    Zidane      5                     5
# 413892    CA   M  2023      Zyan      5                     3
# 413893    CA   M  2023      Zyir      5                     3
#
# [413894 rows x 6 columns]

# %% [markdown]
# # Q.8
#
# Use .str.split() to sample the names with 'ad' string and show first 10 samples.

# %%
# Step 4: Filter names that contain 'ad'
names_with_ad = babynames[babynames['Name'].str.contains('ad')]

# Step 5: Use .str.split() to split names containing 'ad' (for demonstration purposes)
names_with_ad['split_name'] = names_with_ad['Name'].str.split('ad')

# Display the first 10 samples
display(names_with_ad.head(10))
# Out:
# <ipython-input-35-28226b72b092>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_with_ad['split_name'] = names_with_ad['Name'].str.split('ad')
#     State Sex  Year      Name  Count  name_length_modified  split_name
# 19     CA   F  1910    Gladys     63                     5    [Gl, ys]
# 96     CA   F  1910  Madeline     17                     7  [M, eline]
# 136    CA   F  1910     Sadie     10                     4     [S, ie]
# 257    CA   F  1911    Gladys     61                     5    [Gl, ys]
# 346    CA   F  1911    Nadine     14                     5    [N, ine]
# 376    CA   F  1911  Madeline     11                     7  [M, eline]
# 472    CA   F  1911     Madge      5                     4     [M, ge]
# 480    CA   F  1911     Sadie      5                     4     [S, ie]
# 506    CA   F  1912    Gladys     87                     5    [Gl, ys]
# 569    CA   F  1912  Madeline     31                     7  [M, eline]

# %% [markdown]
# More on str methods when we'll study regular expressions in this course. Note that there are other approaches that we can use to find the same answer as above.

# %% [markdown]
# # Q.9
#  Sort names by their length using lambda function.

# %%
from os import name
names_with_ad = babynames[babynames['Name'].str.contains('ad')]
names_with_ad['split_name'] = names_with_ad['Name'].str.split('ad')
names_with_ad['name_length'] = names_with_ad['Name'].apply(lambda x: len(x))
# Out:
# <ipython-input-36-79806fb4c5a1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_with_ad['split_name'] = names_with_ad['Name'].str.split('ad')
# <ipython-input-36-79806fb4c5a1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_with_ad['name_length'] = names_with_ad['Name'].apply(lambda x: len(x))

# %% [markdown]
# # Q.10
# 1: The code randomly mixes up the list of baby names. Why might someone want to do this, and how could it affect the analysis of the names?
#
# 2: After mixing, the code figures out how long each baby name is. Why would we care about name lengths, and what can this tell us about the names?
#
# 3: The code arranges the name lengths from longest to shortest. Why might we want to do this, and what could it help us find in the data?
#
# 4: The code finds the order of baby names based on their lengths and shows us the first few names in this new order. When might we need to organize names this way, and what might we discover from the first few names in this order?

# %%
#Part1, shuffling can be done using sample(frac=1)
#1: The code randomly mixes up the list of baby names. Why might someone want to do this, and how could it affect the analysis of the names?
p1=babynames.sample(frac=1)
print(p1)

#Part2
#After mixing, the code figures out how long each baby name is. Why would we care about name lengths, and what can this tell us about the names?
p2=babynames.sample(frac=1)
p2['name_length']=p2['Name'].str.len()
print(p2)

#Part3
#The code arranges the name lengths from longest to shortest. Why might we want to do this, and what could it help us find in the data?
p3=babynames.sample(frac=1)
p3['name_length']=p3['Name'].str.len()
p3=p3.sort_values(by='name_length',ascending=False)
print(p3)

#Part4
#The code finds the order of baby names based on their lengths and shows us the first few names in this new order. When might we need to organize names this way, and what might we discover from the first few names in this order?
p4=babynames.sample(frac=1)
p4['name_length']=p4['Name'].str.len()
p4=p4.sort_values(by='name_length',ascending=False)
print(p4)
# Out:
#        State Sex  Year        Name  Count  name_length_modified
# 227206    CA   F  2019     Jenelle      9                     6
# 191894    CA   F  2010      Daiana      9                     5
# 355764    CA   M  2003     Conrado      6                     6
# 183715    CA   F  2008  Brooklynne      8                     9
# 212245    CA   F  2015      Kellie      8                     5
# ...      ...  ..   ...         ...    ...                   ...
# 104348    CA   F  1987      Marlin     11                     5
# 821       CA   F  1913        Lois     83                     3
# 165296    CA   F  2004      Kamila     37                     5
# 254645    CA   M  1934       Elias     13                     4
# 270789    CA   M  1956    Clifford    262                     7
#
# [413894 rows x 6 columns]
#        State Sex  Year       Name  Count  name_length_modified  name_length
# 372158    CA   M  2009   Channing     10                     7            8
# 255979    CA   M  1937       Gary    650                     3            4
# 8114      CA   F  1926  Hortencia     13                     8            9
# 56353     CA   F  1967     Celene      7                     5            6
# 7606      CA   F  1925    Earline      6                     6            7
# ...      ...  ..   ...        ...    ...                   ...          ...
# 191568    CA   F  2010     Carson     11                     5            6
# 77001     CA   F  1977     Jeremy     14                     5            6
# 321837    CA   M  1990    Rojelio     23                     6            7
# 106709    CA   F  1988       Lina     28                     3            4
# 405418    CA   M  2021     Carlos    488                     5            6
#
# [413894 rows x 7 columns]
#        State Sex  Year             Name  Count  name_length_modified  \
# 341130    CA   M  1997  Ryanchristopher      5                    14
# 325441    CA   M  1991  Ryanchristopher      7                    14
# 331124    CA   M  1993  Ryanchristopher      5                    14
# 320534    CA   M  1989  Franciscojavier      6                    14
# 331009    CA   M  1993  Johnchristopher      5                    14
# ...      ...  ..   ...              ...    ...                   ...
# 25997     CA   F  1948               Lu      7                     1
# 353346    CA   M  2002               Al      5                     1
# 250111    CA   M  1926               Ed     10                     1
# 98649     CA   F  1985               Le      8                     1
# 17192     CA   F  1940               Jo    169                     1
#
#         name_length
# 341130           15
# 325441           15
# 331124           15
# 320534           15
# 331009           15
# ...             ...
# 25997             2
# 353346            2
# 250111            2
# 98649             2
# 17192             2
#
# [413894 rows x 7 columns]
#        State Sex  Year             Name  Count  name_length_modified  \
# 343125    CA   M  1998  Franciscojavier      6                    14
# 341130    CA   M  1997  Ryanchristopher      5                    14
# 348093    CA   M  2000  Franciscojavier      6                    14
# 325441    CA   M  1991  Ryanchristopher      7                    14
# 320534    CA   M  1989  Franciscojavier      6                    14
# ...      ...  ..   ...              ...    ...                   ...
# 86899     CA   F  1981               Ha     17                     1
# 313678    CA   M  1986               Ed      7                     1
# 358991    CA   M  2004               Tj      5                     1
# 254073    CA   M  1933               Al     19                     1
# 238262    CA   F  2022               An      8                     1
#
#         name_length
# 343125           15
# 341130           15
# 348093           15
# 325441           15
# 320534           15
# ...             ...
# 86899             2
# 313678            2
# 358991            2
# 254073            2
# 238262            2
#
# [413894 rows x 7 columns]

# %%
p1 = babynames.sample(frac=1).reset_index(drop=True)
print(p1)

babynames['Name_Length'] = babynames['Name'].apply(len)
print(babynames)

sorted_by_length = babynames.sort_values(by='Name_Length', ascending=False)
print(sorted_by_length)


first_few_names = sorted_by_length.head()
print(first_few_names[['Name', 'Name_Length']])
# Out:
#        State Sex  Year     Name  Count  name_length_modified
# 0         CA   F  2013   Aaliya     14                     5
# 1         CA   F  1948    Vicky     69                     4
# 2         CA   F  1970  Angelia     22                     6
# 3         CA   F  1977   Hilary     80                     5
# 4         CA   M  2018    Rylan     76                     4
# ...      ...  ..   ...      ...    ...                   ...
# 413889    CA   M  2004  Brandyn     13                     6
# 413890    CA   F  2010   Sylvie     21                     5
# 413891    CA   F  1978  Eugenia     23                     6
# 413892    CA   M  1925      Pat     11                     2
# 413893    CA   M  1958     Jake      7                     3
#
# [413894 rows x 6 columns]
#        State Sex  Year      Name  Count  name_length_modified  Name_Length
# 0         CA   F  1910      Mary    295                     3            4
# 1         CA   F  1910     Helen    239                     4            5
# 2         CA   F  1910   Dorothy    220                     6            7
# 3         CA   F  1910  Margaret    163                     7            8
# 4         CA   F  1910   Frances    134                     6            7
# ...      ...  ..   ...       ...    ...                   ...          ...
# 413889    CA   M  2023      Ziah      5                     3            4
# 413890    CA   M  2023    Ziaire      5                     5            6
# 413891    CA   M  2023    Zidane      5                     5            6
# 413892    CA   M  2023      Zyan      5                     3            4
# 413893    CA   M  2023      Zyir      5                     3            4
#
# [413894 rows x 7 columns]
#        State Sex  Year             Name  Count  name_length_modified  \
# 341130    CA   M  1997  Ryanchristopher      5                    14
# 348093    CA   M  2000  Franciscojavier      6                    14
# 331124    CA   M  1993  Ryanchristopher      5                    14
# 337819    CA   M  1996  Franciscojavier      8                    14
# 317627    CA   M  1988  Franciscojavier     10                    14
# ...      ...  ..   ...              ...    ...                   ...
# 114679    CA   F  1990               An     10                     1
# 352991    CA   M  2002               Jc      7                     1
# 244981    CA   M  1916               Al      8                     1
# 118952    CA   F  1991               Vi      8                     1
# 325806    CA   M  1991               Cj      5                     1
#
#         Name_Length
# 341130           15
# 348093           15
# 331124           15
# 337819           15
# 317627           15
# ...             ...
# 114679            2
# 352991            2
# 244981            2
# 118952            2
# 325806            2
#
# [413894 rows x 7 columns]
#                    Name  Name_Length
# 341130  Ryanchristopher           15
# 348093  Franciscojavier           15
# 331124  Ryanchristopher           15
# 337819  Franciscojavier           15
# 317627  Franciscojavier           15

# %% [markdown]
# # Bonus Question
#
# 1: How can you use the .sample() method to randomly select a single row from the babynames DataFrame, and what is the purpose of such a selection?
#
# 2: Suppose you want to generate a random sample of 10 baby names from the babynames DataFrame. How would you use the .sample() method to achieve this, and what parameters or arguments would you specify?
#
# 3: In a scenario where you need to ensure reproducibility, explain how you can set a random seed when using the .sample() method in pandas. Why might this be important in certain data analysis tasks?
#
# 4: You want to perform a bootstrap resampling analysis on the baby names data in the babynames DataFrame. Describe how you can repeatedly sample with replacement using .sample() to create multiple bootstrap samples for statistical analysis

# %%
# 1
random_row = babynames.sample(n=1)
print(random_row)


# 2
random_sample = babynames.sample(n=10)
print(random_sample)


# 3
random_sample = babynames.sample(n=10, random_state=42)
print(random_sample)


# 4
random_seed = 42
n_bootstrap_samples = 1000
sample_size = len(babynames)
bootstrap_means = []
for _ in range(n_bootstrap_samples):

    bootstrap_sample = babynames.sample(n=sample_size, replace=True, random_state=random_seed)


    bootstrap_mean = bootstrap_sample['Count'].mean()


    bootstrap_means.append(bootstrap_mean)

# Convert the list to a DataFrame for further analysis
bootstrap_results = pd.DataFrame(bootstrap_means, columns=['Bootstrap_Mean'])

# Display the first few results
print(bootstrap_results.head())
# Out:
#        State Sex  Year   Name  Count  name_length_modified  Name_Length
# 282212    CA   M  1966  Casey     78                     4            5
#        State Sex  Year       Name  Count  name_length_modified  Name_Length
# 110150    CA   F  1989      Edlin     25                     4            5
# 45866     CA   F  1962        Amy    366                     2            3
# 163071    CA   F  2003        Mea      8                     2            3
# 202668    CA   F  2013      Cielo     31                     4            5
# 344827    CA   M  1999      Korey     12                     4            5
# 304577    CA   M  1981     Layton      5                     5            6
# 109827    CA   F  1989     Serina     43                     5            6
# 303413    CA   M  1981    Estevan     35                     6            7
# 18958     CA   F  1942     Denise     44                     5            6
# 118363    CA   F  1991  Madelaine     11                     8            9
#        State Sex  Year      Name  Count  name_length_modified  Name_Length
# 340950    CA   M  1997    Farris      5                     5            6
# 371864    CA   M  2009    Kamran     14                     5            6
# 409483    CA   M  2022    Manolo     16                     5            6
# 359211    CA   M  2005   Donovan    279                     6            7
# 251683    CA   M  1929   Alfredo     66                     6            7
# 162706    CA   F  2003     Naila     10                     4            5
# 7395      CA   F  1925  Charlene     13                     7            8
# 381534    CA   M  2012      Arin      6                     3            4
# 401098    CA   M  2019      Taha     13                     3            4
# 315333    CA   M  1987    Ryland     12                     5            6
#    Bootstrap_Mean
# 0       78.253345
# 1       78.253345
# 2       78.253345
# 3       78.253345
# 4       78.253345
