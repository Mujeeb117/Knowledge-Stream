# %%
import pandas as pd

# %%
df=pd.read_csv("elections.csv")
df
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
df.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
df.tail()
# Out:
#      Year       Candidate        Party  Popular vote Result          %
# 177  2016      Jill Stein        Green       1457226   loss   1.073699
# 178  2020    Joseph Biden   Democratic      81268924    win  51.311515
# 179  2020    Donald Trump   Republican      74216154   loss  46.858542
# 180  2020    Jo Jorgensen  Libertarian       1865724   loss   1.177979
# 181  2020  Howard Hawkins        Green        405035   loss   0.255731

# %%
df=pd.read_csv('elections.csv' , index_col="Year")
df
# Out:
#               Candidate                  Party  Popular vote Result          %
# Year
# 1824     Andrew Jackson  Democratic-Republican        151271   loss  57.210122
# 1824  John Quincy Adams  Democratic-Republican        113142    win  42.789878
# 1828     Andrew Jackson             Democratic        642806    win  56.203927
# 1828  John Quincy Adams    National Republican        500897   loss  43.796073
# 1832     Andrew Jackson             Democratic        702735    win  54.574789
# ...                 ...                    ...           ...    ...        ...
# 2016         Jill Stein                  Green       1457226   loss   1.073699
# 2020       Joseph Biden             Democratic      81268924    win  51.311515
# 2020       Donald Trump             Republican      74216154   loss  46.858542
# 2020       Jo Jorgensen            Libertarian       1865724   loss   1.177979
# 2020     Howard Hawkins                  Green        405035   loss   0.255731
#
# ...

# %%
df2=pd.read_csv('duplicate.csv')
df2
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %  Unnamed: 6 Result.1
# 0    57.210122         NaN     loss
# ...

# %%
df.columns
# Out:
# Index(['Candidate', 'Party', 'Popular vote', 'Result', '%'], dtype='object')

# %%
df['Party']
# Out:
# Year
# 1824    Democratic-Republican
# 1824    Democratic-Republican
# 1828               Democratic
# 1828      National Republican
# 1832               Democratic
#                 ...
# 2016                    Green
# 2020               Democratic
# 2020               Republican
# 2020              Libertarian
# 2020                    Green
# Name: Party, Length: 182, dtype: object

# %%
df['Result']
# Out:
# Year
# 1824    loss
# 1824     win
# 1828     win
# 1828    loss
# 1832     win
#         ...
# 2016    loss
# 2020     win
# 2020    loss
# 2020    loss
# 2020    loss
# Name: Result, Length: 182, dtype: object

# %%
df[['Party', 'Result']]
# Out:
#                       Party Result
# Year
# 1824  Democratic-Republican   loss
# 1824  Democratic-Republican    win
# 1828             Democratic    win
# 1828    National Republican   loss
# 1832             Democratic    win
# ...                     ...    ...
# 2016                  Green   loss
# 2020             Democratic    win
# 2020             Republican   loss
# 2020            Libertarian   loss
# 2020                  Green   loss
#
# [182 rows x 2 columns]

# %% [markdown]
# # Series

# %%
import pandas as pd

# %%
s=pd.Series(['ABCDE', "FGHIJ", "KLMNO", "PQRST", "UVWX"])
s
# Out:
# 0    ABCDE
# 1    FGHIJ
# 2    KLMNO
# 3    PQRST
# 4     UVWX
# dtype: object

# %%
s=pd.Series(['ABCDE', "FGHIJ", "KLMNO", "PQRST", "UVWX"], index=['10', '20', '30', '40', '50'])
s
# Out:
# 10    ABCDE
# 20    FGHIJ
# 30    KLMNO
# 40    PQRST
# 50     UVWX
# dtype: object

# %%
s[['20' , '40']]
# Out:
# 20    FGHIJ
# 40    PQRST
# dtype: object

# %% [markdown]
# # Data Frame using Pandas

# %%
pd.DataFrame([1,2,3,4,5], columns= ["col"])
# Out:
#    col
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
pd.DataFrame([["qd", 'dqd', 'qdwq', 'lcdv'], ['vds', 'qwd', 'dfw', 'vows']] , columns=['sad', 'happy', 'no', 'yes'])
# Out:
#    sad happy    no   yes
# 0   qd   dqd  qdwq  lcdv
# 1  vds   qwd   dfw  vows

# %%
pd.DataFrame([['fas', 'fwas', 'ok', 'vd', 'aa'], ['zz', 'bb', 'ww', 'vv', 'aa'], ['vs', 'vb', 'bb', 'kk', 'bb']], columns= ['A','B', 'C', 'D', "E"])
# Out:
#      A     B   C   D   E
# 0  fas  fwas  ok  vd  aa
# 1   zz    bb  ww  vv  aa
# 2   vs    vb  bb  kk  bb

# %%
df=pd.read_csv('elections.csv')
df
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
df.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
pd.read_csv('elections.csv', index_col="Result")
# Out:
#         Year          Candidate                  Party  Popular vote  \
# Result
# loss    1824     Andrew Jackson  Democratic-Republican        151271
# win     1824  John Quincy Adams  Democratic-Republican        113142
# win     1828     Andrew Jackson             Democratic        642806
# loss    1828  John Quincy Adams    National Republican        500897
# win     1832     Andrew Jackson             Democratic        702735
# ...      ...                ...                    ...           ...
# loss    2016         Jill Stein                  Green       1457226
# win     2020       Joseph Biden             Democratic      81268924
# loss    2020       Donald Trump             Republican      74216154
# loss    2020       Jo Jorgensen            Libertarian       1865724
# loss    2020     Howard Hawkins                  Green        405035
#
#                 %
# Result
# loss    57.210122
# win     42.789878
# win     56.203927
# loss    43.796073
# win     54.574789
# ...
